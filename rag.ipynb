# %%
# Data Ingestion

import os

from dotenv import load_dotenv

load_dotenv()

# Read your API key
api_key = os.getenv("OPENAI_API_KEY")
if not api_key:
    raise ValueError("OPENAI_API_KEY not found in environment variables!")

# %%
from sentence_transformers import SentenceTransformer

# Load HF embedding model
embedding_model = SentenceTransformer('BAAI/bge-large-en-v1.5')
print(f"✓ Loaded embedding model: BAAI/bge-large-en-v1.5")

def get_embedding(text, input_type="document"):
    """Generate embeddings using Hugging Face model"""
    embedding = embedding_model.encode(text, convert_to_tensor=False)
    return embedding.tolist()
# Out:
# ✓ Loaded embedding model: BAAI/bge-large-en-v1.5

# %%
embeddings = get_embedding("AI TECHNOLOGY")
print(embeddings)
# Out:
# [0.01917918398976326, 0.034076254814863205, -0.014155448414385319, -0.011123940348625183, 0.008389163762331009, -0.0028036769945174456, -0.018184814602136612, -0.0040381792932748795, 0.003224150976166129, 0.033781394362449646, -0.017017804086208344, 0.023310476914048195, -0.013705801218748093, -0.025031737983226776, -0.007939236238598824, 0.0038879583589732647, 0.0019610035233199596, 0.0027043744921684265, 0.0016844150377437472, -0.0020721701439470053, 0.011545512825250626, 0.045777078717947006, -0.042421914637088776, -0.02855719067156315, -0.0338626392185688, 0.028979672119021416, 0.010323243215680122, 0.00826785247772932, 0.07991677522659302, 0.0356597863137722, -0.003495182376354933, -0.018108438700437546, 0.02561355195939541, -0.030184539034962654, -0.008680817671120167, -0.02041185274720192, -0.005613876506686211, -0.01719573512673378, -0.05497545003890991, -0.044544536620378494, -0.011060413904488087, -0.0038015968166291714, -0.02026393823325634, -0.1032286062836647, -0.09280974417924881, 0.05339234694838524, 0.0008411796297878027, -0.030834604054689407, -0.03116675280034542, -0.028605403378605843, -0.040803100913763046, 0.027625441551208496, 0.018659567460417747, -0.008842877112329006, -0.031471822410821915, -0.03389225900173187, -0.007326069287955761, -0.0071684326976537704, -0.021250508725643158, 0.0076760295778512955, 0.09220675379037857, -0.008725020103156567, 0.03396210819482803, -0.030912326648831367, 0.012894706800580025, 0.01146696601063013, 0.03772721812129021, -0.04072132334113121, 0.0007886756211519241, -0.017388371750712395, -0.028524551540613174, 0.013069442473351955, 0.009811819531023502, -0.02546597272157669, 0.00010929488780675456, -0.006081356666982174, -0.002571922494098544, -0.02329195849597454, -0.024846017360687256, -0.011940688826143742, 0.024104727432131767, 0.05378720909357071, -0.03145570307970047, 0.03199021890759468, -0.02154112048447132, -0.035976819694042206, 0.019279388710856438, 0.03681352362036705, -0.0017135465750470757, -0.0036118573043495417, -0.008703400380909443, 0.029904600232839584, 0.00888016913086176, 0.04034547507762909, -0.01793246902525425, 0.017341366037726402, -0.0032429418060928583, 0.050372414290905, -0.014609054662287235, 0.005871674511581659, 0.026313792914152145, 0.08176402747631073, -0.025937160477042198, 0.07422009110450745, -0.02330813556909561, -0.005142023786902428, 0.024805983528494835, -0.01410236768424511, -0.010032306425273418, -0.04957903176546097, -0.0035133264027535915, 0.013140346854
),
#  Document(metadata={'producer': 'Adobe PDF Library 17.0', 'creator': 'Adobe InDesign 20.0 (Windows)', 'creationdate': '2025-02-13T13:05:16-05:00', 'author': 'Fidelity Investments', 'keywords': '2024, Fidelity Investments, Fidelity, Annual Report', 'moddate': '2025-02-13T18:31:58-05:00', 'subject': "Learn how Fidelity's financial strength and operational stability allows us to deliver products and services that meet the needs of our customers and clients.", 'title': '2024 Fidelity Investments Annual Report', 'trapped': '/False', 'source': 'https://www.fidelity.com/bin-public/060_www_fidelity_com/documents/about-fidelity/2024-Fidelity-Investments-Annual-Report.pdf', 'total_pages': 15, 'page': 5, 'page_label': '6'}, page_content='service representative.  \nOur total customers enrolled in \neDelivery increased by 10% to  \n55.6 million, a testament to the  \npaper-elimination efforts at Fidelity.\nWe enhanced the application process \nfor securities-based lines of credit,  \nand 93% of applications were done fully \nonline — allowing most customers access \nto credit in less than three days. \nWe launched the Fidelity Growth \nHub'),
#  Document(metadata={'producer': 'Adobe PDF Library 17.0', 'creator': 'Adobe InDesign 20.0 (Windows)', 'creationdate': '2025-02-13T13:05:16-05:00', 'author': 'Fidelity Investments', 'keywords': '2024, Fidelity Investments, Fidelity, Annual Report', 'moddate': '2025-02-13T18:31:58-05:00', 'subject': "Learn how Fidelity's financial strength and operational stability allows us to deliver products and services that meet the needs of our customers and clients.", 'title': '2024 Fidelity Investments Annual Report', 'trapped': '/False', 'source': 'https://www.fidelity.com/bin-public/060_www_fidelity_com/documents/about-fidelity/2024-Fidelity-Investments-Annual-Report.pdf', 'total_pages': 15, 'page': 5, 'page_label': '6'}, page_content='Hub\nSM, a suite of resources to help \nfinancial advisors sharpen their \napproaches to acquire new clients, \nexpand relationships, and scale \ntheir businesses. \nThe new Fidelity Virtual Assistant \nimproved search capabilities on Fidelity \ndigital channels and delivered more \nresults with quick and easy navigation. \nWe released a new, modernized \nworkflow for opening core brokerage'),
#  Document(metadata={'producer': 'Adobe PDF Library 17.0', 'creator': 'Adobe InDesign 20.0 (Windows)', 'creationdate': '2025-02-13T13:05:16-05:00', 'author': 'Fidelity Investments', 'keywords': '2024, Fidelity Investments, Fidelity, Annual Report', 'moddate': '2025-02-13T18:31:58-05:00', 'subject': "Learn how Fidelity's financial strength and operational stability allows us to deliver products and services that meet the needs of our customers and clients.", 'title': '2024 Fidelity Investments Annual Report', 'trapped': '/False', 'source': 'https://www.fidelity.com/bin-public/060_www_fidelity_com/documents/about-fidelity/2024-Fidelity-Investments-Annual-Report.pdf', 'total_pages': 15, 'page': 5, 'page_label': '6'}, page_content='accounts for individual investors. This \nsimplified infrastructure enhances \nand streamlines our customers’ online \naccount opening experience.\nWe reaffirmed our commitment to \nserving wealth management firms of all \nsizes by introducing new technology \nofferings for small- and mid-sized \nregistered investment advisors. These \ninclude an all-in-one technology stack'),
#  Document(metadata={'producer': 'Adobe PDF Library 17.0', 'creator': 'Adobe InDesign 20.0 (Windows)', 'creationdate': '2025-02-13T13:05:16-05:00', 'author': 'Fidelity Investments', 'keywords': '2024, Fidelity Investments, Fidelity, Annual Report', 'moddate': '2025-02-13T18:31:58-05:00', 'subject': "Learn how Fidelity's financial strength and operational stability allows us to deliver products and services that meet the needs of our customers and clients.", 'title': '2024 Fidelity Investments Annual Report', 'trapped': '/False', 'source': 'https://www.fidelity.com/bin-public/060_www_fidelity_com/documents/about-fidelity/2024-Fidelity-Investments-Annual-Report.pdf', 'total_pages': 15, 'page': 5, 'page_label': '6'}, page_content='and advisory bundle that features Fidelity \nManaged Account Xchange® (FMAX)\nEssentials, a new streamlined managed \naccount platform. The goal is to reduce \ntwo common technology barriers for \nsmaller firms: resources and cost. We \nalso helped wealth management firms \ngrow their businesses by increasing \nstraight-through-processing of new \naccounts to 50%, an 11-point increase'),
#  Document(metadata={'producer': 'Adobe PDF Library 17.0', 'creator': 'Adobe InDesign 20.0 (Windows)', 'creationdate': '2025-02-13T13:05:16-05:00', 'author': 'Fidelity Investments', 'keywords': '2024, Fidelity Investments, Fidelity, Annual Report', 'moddate': '2025-02-13T18:31:58-05:00', 'subject': "Learn how Fidelity's financial strength and operational stability allows us to deliver products and services that meet the needs of our customers and clients.", 'title': '2024 Fidelity Investments Annual Report', 'trapped': '/False', 'source': 'https://www.fidelity.com/bin-public/060_www_fidelity_com/documents/about-fidelity/2024-Fidelity-Investments-Annual-Report.pdf', 'total_pages': 15, 'page': 5, 'page_label': '6'}, page_content='from the prior year.\n8\nABOUT FIDELITY\nCHAIRMAN’S LETTER\nFINANCIAL AND  \nOPERATING RESULTS\nCUSTOMER \nENGAGEMENT\nDIGITAL CUSTOMER \nEXPERIENCE\nTECHNOLOGY\nNEW PRODUCTS \nAND SERVICES\nOUR ASSOCIATES\nOUR COMMUNITIES\nAWARDS\nDISCLOSURES'),
#  Document(metadata={'producer': 'Adobe PDF Library 17.0', 'creator': 'Adobe InDesign 20.0 (Windows)', 'creationdate': '2025-02-13T13:05:16-05:00', 'author': 'Fidelity Investments', 'keywords': '2024, Fidelity Investments, Fidelity, Annual Report', 'moddate': '2025-02-13T18:31:58-05:00', 'subject': "Learn how Fidelity's financial strength and operational stability allows us to deliver products and services that meet the needs of our customers and clients.", 'title': '2024 Fidelity Investments Annual Report', 'trapped': '/False', 'source': 'https://www.fidelity.com/bin-public/060_www_fidelity_com/documents/about-fidelity/2024-Fidelity-Investments-Annual-Report.pdf', 'total_pages': 15, 'page': 6, 'page_label': '7'}, page_content='Technology\nFidelity continues to \nmodernize and enhance \nour technology platforms \nand solutions, enabling us \nto scale efforts and reduce \ncustomer friction. \nFidelity continually invests in cybersecurity and customer data protection, \nincluding multi-factor authentication (MFA), which increased from 15% \nto 88% enrollment.\nThe new Ops Workstation improves the tools to monitor, manage, and scale'),
#  Document(metadata={'producer': 'Adobe PDF Library 17.0', 'creator': 'Adobe InDesign 20.0 (Windows)', 'creationdate': '2025-02-13T13:05:16-05:00', 'author': 'Fidelity Investments', 'keywords': '2024, Fidelity Investments, Fidelity, Annual Report', 'moddate': '2025-02-13T18:31:58-05:00', 'subject': "Learn how Fidelity's financial strength and operational stability allows us to deliver products and services that meet the needs of our customers and clients.", 'title': '2024 Fidelity Investments Annual Report', 'trapped': '/False', 'source': 'https://www.fidelity.com/bin-public/060_www_fidelity_com/documents/about-fidelity/2024-Fidelity-Investments-Annual-Report.pdf', 'total_pages': 15, 'page': 6, 'page_label': '7'}, page_content='our operations, which helps us deliver an outstanding customer experience.\nPayroll integration with Gusto, a non-Fidelity business that offers payroll and benefits \nprocessing, helped streamline clients’ payroll setup from over a week to under a \nminute by syncing equity management, HR, and payroll. \nSaifr®, a Fidelity business that offers compliance solutions, expanded its suite of'),
#  Document(metadata={'producer': 'Adobe PDF Library 17.0', 'creator': 'Adobe InDesign 20.0 (Windows)', 'creationdate': '2025-02-13T13:05:16-05:00', 'author': 'Fidelity Investments', 'keywords': '2024, Fidelity Investments, Fidelity, Annual Report', 'moddate': '2025-02-13T18:31:58-05:00', 'subject': "Learn how Fidelity's financial strength and operational stability allows us to deliver products and services that meet the needs of our customers and clients.", 'title': '2024 Fidelity Investments Annual Report', 'trapped': '/False', 'source': 'https://www.fidelity.com/bin-public/060_www_fidelity_com/documents/about-fidelity/2024-Fidelity-Investments-Annual-Report.pdf', 'total_pages': 15, 'page': 6, 'page_label': '7'}, page_content='regulatory technology offerings by acquiring Giant Oak Search Technology to help  \nfinancial services firms navigate rising industry risks. Saifr® also forged a new collaboration \nwith Microsoft, and is now available in the Microsoft Azure AI model catalog.\nFidelity Stock Transfer, a digital-first transfer agent designed for publicly traded'),
#  Document(metadata={'producer': 'Adobe PDF Library 17.0', 'creator': 'Adobe InDesign 20.0 (Windows)', 'creationdate': '2025-02-13T13:05:16-05:00', 'author': 'Fidelity Investments', 'keywords': '2024, Fidelity Investments, Fidelity, Annual Report', 'moddate': '2025-02-13T18:31:58-05:00', 'subject': "Learn how Fidelity's financial strength and operational stability allows us to deliver products and services that meet the needs of our customers and clients.", 'title': '2024 Fidelity Investments Annual Report', 'trapped': '/False', 'source': 'https://www.fidelity.com/bin-public/060_www_fidelity_com/documents/about-fidelity/2024-Fidelity-Investments-Annual-Report.pdf', 'total_pages': 15, 'page': 6, 'page_label': '7'}, page_content='companies, ended 2024 with four onboarded clients. The business launched to the \npublic in January 2025.\nCatchlight®, a growth platform solution for wealth management firms, expanded capabilities with the rollout \nof new models for optimizing leads, including proprietary lead-routing and predictive lead-conversion models.'),
#  Document(metadata={'producer': 'Adobe PDF Library 17.0', 'creator': 'Adobe InDesign 20.0 (Windows)', 'creationdate': '2025-02-13T13:05:16-05:00', 'author': 'Fidelity Investments', 'keywords': '2024, Fidelity Investments, Fidelity, Annual Report', 'moddate': '2025-02-13T18:31:58-05:00', 'subject': "Learn how Fidelity's financial strength and operational stability allows us to deliver products and services that meet the needs of our customers and clients.", 'title': '2024 Fidelity Investments Annual Report', 'trapped': '/False', 'source': 'https://www.fidelity.com/bin-public/060_www_fidelity_com/documents/about-fidelity/2024-Fidelity-Investments-Annual-Report.pdf', 'total_pages': 15, 'page': 6, 'page_label': '7'}, page_content='Fidelity expanded its relationship with Envestnet, a third-party firm, to deliver a next-generation unified \nwealth and advisory platform for wealth management firms, building on the success of FMAX.\nABOUT FIDELITY\nCHAIRMAN’S LETTER\nFINANCIAL AND  \nOPERATING RESULTS\nCUSTOMER \nENGAGEMENT\nDIGITAL CUSTOMER \nEXPERIENCE\nTECHNOLOGY\nNEW PRODUCTS \nAND SERVICES\nOUR ASSOCIATES\nOUR COMMUNITIES\nAWARDS'),
#  Document(metadata={'producer': 'Adobe PDF Library 17.0', 'creator': 'Adobe InDesign 20.0 (Windows)', 'creationdate': '2025-02-13T13:05:16-05:00', 'author': 'Fidelity Investments', 'keywords': '2024, Fidelity Investments, Fidelity, Annual Report', 'moddate': '2025-02-13T18:31:58-05:00', 'subject': "Learn how Fidelity's financial strength and operational stability allows us to deliver products and services that meet the needs of our customers and clients.", 'title': '2024 Fidelity Investments Annual Report', 'trapped': '/False', 'source': 'https://www.fidelity.com/bin-public/060_www_fidelity_com/documents/about-fidelity/2024-Fidelity-Investments-Annual-Report.pdf', 'total_pages': 15, 'page': 6, 'page_label': '7'}, page_content='AWARDS\nDISCLOSURES'),
#  Document(metadata={'producer': 'Adobe PDF Library 17.0', 'creator': 'Adobe InDesign 20.0 (Windows)', 'creationdate': '2025-02-13T13:05:16-05:00', 'author': 'Fidelity Investments', 'keywords': '2024, Fidelity Investments, Fidelity, Annual Report', 'moddate': '2025-02-13T18:31:58-05:00', 'subject': "Learn how Fidelity's financial strength and operational stability allows us to deliver products and services that meet the needs of our customers and clients.", 'title': '2024 Fidelity Investments Annual Report', 'trapped': '/False', 'source': 'https://www.fidelity.com/bin-public/060_www_fidelity_com/documents/about-fidelity/2024-Fidelity-Investments-Annual-Report.pdf', 'total_pages': 15, 'page': 7, 'page_label': '8'}, page_content='New Products and Services\nFidelity developed new solutions and enhanced investment options \nto strengthen the financial well-being of current and new customers. \nNEW SOLUTIONS \nFidelity Medicare Services expanded to residents of all 50 U.S. states and \nWashington, D.C., delivering more than 42,000 Medicare guidance discussions.'),
#  Document(metadata={'producer': 'Adobe PDF Library 17.0', 'creator': 'Adobe InDesign 20.0 (Windows)', 'creationdate': '2025-02-13T13:05:16-05:00', 'author': 'Fidelity Investments', 'keywords': '2024, Fidelity Investments, Fidelity, Annual Report', 'moddate': '2025-02-13T18:31:58-05:00', 'subject': "Learn how Fidelity's financial strength and operational stability allows us to deliver products and services that meet the needs of our customers and clients.", 'title': '2024 Fidelity Investments Annual Report', 'trapped': '/False', 'source': 'https://www.fidelity.com/bin-public/060_www_fidelity_com/documents/about-fidelity/2024-Fidelity-Investments-Annual-Report.pdf', 'total_pages': 15, 'page': 7, 'page_label': '8'}, page_content='Fidelity Prime Services, a prime brokerage platform for asset managers, \nannounced a strategic relationship with Stone Coast Fund Services, a leading \nindependent, privately-owned fund administrator, to create a holistic, end-to-end \noffering for hedge funds. \nFidelity increased its Health Savings Account (HSA) market share to 20%,'),
#  Document(metadata={'producer': 'Adobe PDF Library 17.0', 'creator': 'Adobe InDesign 20.0 (Windows)', 'creationdate': '2025-02-13T13:05:16-05:00', 'author': 'Fidelity Investments', 'keywords': '2024, Fidelity Investments, Fidelity, Annual Report', 'moddate': '2025-02-13T18:31:58-05:00', 'subject': "Learn how Fidelity's financial strength and operational stability allows us to deliver products and services that meet the needs of our customers and clients.", 'title': '2024 Fidelity Investments Annual Report', 'trapped': '/False', 'source': 'https://www.fidelity.com/bin-public/060_www_fidelity_com/documents/about-fidelity/2024-Fidelity-Investments-Annual-Report.pdf', 'total_pages': 15, 'page': 7, 'page_label': '8'}, page_content='eliminating the gap with the leading provider. By prioritizing investments in the \nHSA product lineup, the business achieved 40% growth in assets and 20% growth \nin funded accounts.\nFidelity introduced the Student Debt Retirement employer benefit, an \ninnovative workplace solution to help employees boost retirement savings while \npaying down student loan debt.\n9'),
# ...
#  Document(metadata={'producer': 'Adobe PDF Library 17.0', 'creator': 'Adobe InDesign 20.0 (Windows)', 'creationdate': '2025-02-13T13:05:16-05:00', 'author': 'Fidelity Investments', 'keywords': '2024, Fidelity Investments, Fidelity, Annual Report', 'moddate': '2025-02-13T18:31:58-05:00', 'subject': "Learn how Fidelity's financial strength and operational stability allows us to deliver products and services that meet the needs of our customers and clients.", 'title': '2024 Fidelity Investments Annual Report', 'trapped': '/False', 'source': 'https://www.fidelity.com/bin-public/060_www_fidelity_com/documents/about-fidelity/2024-Fidelity-Investments-Annual-Report.pdf', 'total_pages': 15, 'page': 13, 'page_label': '14'}, page_content
),
#  Document(metadata={'producer': 'Adobe PDF Library 17.0', 'creator': 'Adobe InDesign 20.0 (Windows)', 'creationdate': '2025-02-13T13:05:16-05:00', 'author': 'Fidelity Investments', 'keywords': '2024, Fidelity Investments, Fidelity, Annual Report', 'moddate': '2025-02-13T18:31:58-05:00', 'subject': "Learn how Fidelity's financial strength and operational stability allows us to deliver products and services that meet the needs of our customers and clients.", 'title': '2024 Fidelity Investments Annual Report', 'trapped': '/False', 'source': 'https://www.fidelity.com/bin-public/060_www_fidelity_com/documents/about-fidelity/2024-Fidelity-Investments-Annual-Report.pdf', 'total_pages': 15, 'page': 13, 'page_label': '14'}, page_content='registered securities. \nThe performance of each fund or funds will not reflect the specific return an investor would realize \nif the investor actually purchased cryptocurrency. Investors in either fund will not have any rights \nthat cryptocurrency holders have and will not have the right to receive any redemption proceeds \nin the underlying cryptocurrency. \nABOUT FIDELITY\nCHAIRMAN’S LETTER'),
#  Document(metadata={'producer': 'Adobe PDF Library 17.0', 'creator': 'Adobe InDesign 20.0 (Windows)', 'creationdate': '2025-02-13T13:05:16-05:00', 'author': 'Fidelity Investments', 'keywords': '2024, Fidelity Investments, Fidelity, Annual Report', 'moddate': '2025-02-13T18:31:58-05:00', 'subject': "Learn how Fidelity's financial strength and operational stability allows us to deliver products and services that meet the needs of our customers and clients.", 'title': '2024 Fidelity Investments Annual Report', 'trapped': '/False', 'source': 'https://www.fidelity.com/bin-public/060_www_fidelity_com/documents/about-fidelity/2024-Fidelity-Investments-Annual-Report.pdf', 'total_pages': 15, 'page': 13, 'page_label': '14'}, page_content='CHAIRMAN’S LETTER\nFINANCIAL AND  \nOPERATING RESULTS\nCUSTOMER \nENGAGEMENT\nDIGITAL CUSTOMER \nEXPERIENCE\nTECHNOLOGY\nNEW PRODUCTS \nAND SERVICES\nOUR ASSOCIATES\nOUR COMMUNITIES\nAWARDS\nDISCLOSURES'),
#  Document(metadata={'producer': 'Adobe PDF Library 17.0', 'creator': 'Adobe InDesign 20.0 (Windows)', 'creationdate': '2025-02-13T13:05:16-05:00', 'author': 'Fidelity Investments', 'keywords': '2024, Fidelity Investments, Fidelity, Annual Report', 'moddate': '2025-02-13T18:31:58-05:00', 'subject': "Learn how Fidelity's financial strength and operational stability allows us to deliver products and services that meet the needs of our customers and clients.", 'title': '2024 Fidelity Investments Annual Report', 'trapped': '/False', 'source': 'https://www.fidelity.com/bin-public/060_www_fidelity_com/documents/about-fidelity/2024-Fidelity-Investments-Annual-Report.pdf', 'total_pages': 15, 'page': 14, 'page_label': '15'}, page_content='FIDELITY .COM \nCORPORATE HEADQUARTERS  \n245 Summer Street, Boston, Massachusetts 02210 \nFidelity Brokerage Services LLC, Member NYSE, SIPC, 900 Salem Street, Smithfield, RI 02917 \nFidelity Distributors Company LLC, 500 Salem Street, Smithfield, RI 02917 \nNational Financial Services LLC, Member NYSE, SIPC, 245 Summer Street, Boston, MA 02110'),
#  Document(metadata={'producer': 'Adobe PDF Library 17.0', 'creator': 'Adobe InDesign 20.0 (Windows)', 'creationdate': '2025-02-13T13:05:16-05:00', 'author': 'Fidelity Investments', 'keywords': '2024, Fidelity Investments, Fidelity, Annual Report', 'moddate': '2025-02-13T18:31:58-05:00', 'subject': "Learn how Fidelity's financial strength and operational stability allows us to deliver products and services that meet the needs of our customers and clients.", 'title': '2024 Fidelity Investments Annual Report', 'trapped': '/False', 'source': 'https://www.fidelity.com/bin-public/060_www_fidelity_com/documents/about-fidelity/2024-Fidelity-Investments-Annual-Report.pdf', 'total_pages': 15, 'page': 14, 'page_label': '15'}, page_content='The third-party trademarks and service marks appearing herein are the property of  \ntheir respective owners. All other trademarks and service marks appearing herein are  \nthe property of FMR LLC or an affiliated company and may be registered. \n© 2025 FMR LLC. All rights reserved. FMR LLC is a privately owned company. \n1184262.1.0')]

# %%
## DOCS to prepare for insertions

docs_to_insert = [{
    "text"  : doc.page_content,
    "embedding" : get_embedding(doc.page_content)
} for doc in documents]

# %%
# Print the text of the first 5 documents in the final list
for i, doc in enumerate(docs_to_insert[:5]):
    print(f"--- Document {i} ---")
    print(doc['text'])

# Check the total count
print(f"\nTotal documents successfully inserted: {len(docs_to_insert)}")
# Out:
# --- Document 0 ---
# Annual Report
# 2024
# --- Document 1 ---
# About Fidelity
# Fidelity’s mission is to strengthen the
# financial well-being of our customers
# and deliver better outcomes for the
# clients and businesses we serve.
# Fidelity’s strength comes from the
# scale of our diversified, market-
# leading financial services businesses
# that serve individuals, families,
# employers, wealth management
# firms, and institutions. With assets
# --- Document 2 ---
# under administration of $15.1 trillion,
# including discretionary assets of
# $5.9 trillion, we focus on meeting
# the unique needs of a broad and
# growing customer base. Privately
# held for 78 years, Fidelity employs
# more than 77,000 associates across
# North America, Europe, Asia, and
# Australia. For more information,
# visit Fidelity.com.
# 1
# Customer Engagement
# --- Document 3 ---
# Customer Engagement
# Our robust service offerings allow us to meet our customers where they are — whether that is in
# person, on social media, over the phone, or through digital chat.
# Fidelity Wealth, Brokerage,
# or Workplace Investing
# customers who had a live or
# digital plan interaction
# 2
# 8.8 million
# Up 14% from 2023
# Retail customer appointments
# in Investor Centers and
# Regional Centers
# 3
# --- Document 4 ---
# Regional Centers
# 3
# 5.5 million
# Up 13% from 2023
# Unique customers engaging with Fidelity.com,
# NetBenefits.com, the Fidelity Investments
# Mobile App, or the NetBenefits Mobile App
# 4
# 39.2 million
# Up 12% from 2023
# Social media service
# interactions5
# 2.8 millio
# n
# Up 17% from 2023
# Daily Average Trades
# 3.5 million
# Up 35% from 2023
# Calls into Fidelity Wealth, Brokerage,
#
# Total documents successfully inserted: 94

# %%
from pydantic.v1 import BaseModel
import chromadb

# Define where to save the database
PERSIST_DIR = "./chroma_db_data"

# Initialize Persistent Client (this creates the database)
client = chromadb.PersistentClient(path=PERSIST_DIR)

print(f"✓ ChromaDB created at: {PERSIST_DIR}")

# %%
collection = client.get_or_create_collection(
    name="ragpdf")

print(f"✓ Created cluster: ragpdf")

# %%
import uuid

ids = [str(uuid.uuid4()) for _ in docs_to_insert]
documents = [doc["text"] for doc in docs_to_insert]
embeddings = [doc["embedding"] for doc in docs_to_insert]

# Insert
collection.add(
    ids=ids,
    documents=documents,
    embeddings=embeddings
    )

collection.count()
collection

# %%
#### PHASE 2


import chromadb
import uuid

# Connect to ChromaDB
client = chromadb.PersistentClient(path="./chroma_db_data")

# Create collection with vector index configuration
collection = client.get_or_create_collection(
    name="ragpdf",
    metadata={
        "hnsw:space": "cosine",
        "hnsw:construction_ef": 200,
        "hnsw:search_ef": 100,
        "hnsw:M": 16
    }
)

your_ids = [str(uuid.uuid4()) for _ in docs_to_insert]
your_texts = [doc["text"] for doc in docs_to_insert]
your_embeddings = [doc["embedding"] for doc in docs_to_insert]

collection.add(
    ids=your_ids,
    documents=your_texts,
    embeddings=your_embeddings
)

print(f"✓ Vector search index created with {collection.count()} documents")

# %%
results = collection.get(
    limit=5,
    include=['documents', 'embeddings'] # Explicitly ask for text and embeddings
)

# %%
results

# %%
def get_retrieved_context(query_text):
    # 1. Embed the input query text
    query_embedding = get_embedding(query_text)

    # 2. Vector Search ChromaDB
    results = collection.query(
        query_embeddings=[query_embedding],
        n_results=5,
        include=['documents']
    )

    retrieved_documents = results['documents'][0]
    context_string = "\n---\n".join(retrieved_documents)


    return context_string

# %%
#### Phase 3


from openai import OpenAI

# Define the question
query = "“According to the retrieved text, what does Fidelity emphasize about supporting customers?"

# 1. RETRIEVAL: Get the context string using the corrected function
context_string = get_retrieved_context(query)

# 2. GENERATION: Construct the RAG Prompt
rag_prompt = f"""
Use ONLY the provided context to answer the question.
If the answer is not in the context, state that explicitly.

QUESTION: {query}

CONTEXT:
{context_string}
"""

# 3. LLM API Call (Corrected message format)
openai_client = OpenAI()
model_name = "gpt-4o"

completion = openai_client.chat.completions.create(
    model=model_name,
    messages=[

        # Fix 2: User message contains the entire RAG prompt
        {"role": "user", "content": rag_prompt}
    ]
)

# %%
# Output the final answer
final_answer = completion.choices[0].message.content
print("\n--- LLM Final Answer ---")
print(final_answer)
